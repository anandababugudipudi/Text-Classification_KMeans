# %% [markdown]
# ### **Import necessary packages**

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import collections
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from pprint import pprint

# %% [markdown]
# ###**Write a function for word tokenization**

# %%
def tokenizer(text):
  tokens = word_tokenize(text)
  stemmer = PorterStemmer()
  tokens = [stemmer.stem(t) for t in tokens if t not in stopwords.words('english')]
  return tokens

# %% [markdown]
# ###**Write a Function to cluster the given sentences**

# %%
def cluster_sentences(sentences, number_of_clusters = 2):
  # Create a Tfidf
  tfidf_vectorizer = TfidfVectorizer(tokenizer = tokenizer, stop_words = stopwords.words('english'), lowercase = True)
  # Buidld a tfidf matrix for sentences
  tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)
  kmeans = KMeans(n_clusters = number_of_clusters)
  kmeans.fit(tfidf_matrix)
  clusters = collections.defaultdict(list)
  for i, label in enumerate(kmeans.labels_):
    clusters[label].append(i)
  return dict(clusters)

# %%
sentences = ["Quantuum physics is quite important in science nowadays.",
             "Software engineering is hotter and hotter topic in the silicon valley",
             "Investing in stocks and trading with them are not that easy",
             "FOREX is the stock market for trading currencies",
             "Warren Buffet is famous for making good investments. He knows stock markets",
             "I have good knowledge of Statistics and mathematics.",
             "I am good at art and singing."]

nclusters = 2
clusters = cluster_sentences(sentences, nclusters)

for cluster in range(nclusters):
    print("CLUSTER ", cluster, ":")
    for i, sentence in enumerate(clusters[cluster]):
        print("\tSENTENCE ", i, ": ", sentences[sentence])
# Out:
# CLUSTER  0 :
# 	SENTENCE  0 :  Quantuum physics is quite important in science nowadays.
# 	SENTENCE  1 :  Software engineering is hotter and hotter topic in the silicon valley
# 	SENTENCE  2 :  I have good knowledge of Statistics and mathematics.
# 	SENTENCE  3 :  I am good at art and singing.
# CLUSTER  1 :
# 	SENTENCE  0 :  Investing in stocks and trading with them are not that easy
# 	SENTENCE  1 :  FOREX is the stock market for trading currencies
# 	SENTENCE  2 :  Warren Buffet is famous for making good investments. He knows stock markets
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'ll", "'re", "'s", "'ve", 'could', 'might', 'must', "n't", 'need', 'sha', 'wo', 'would'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
